# %%
import pandas as pd

# %%
l = ['shiv','222','32e','kcmdk']

df = pd.Series(l,name='col')

# %%
df
# Out:
# 0     shiv
# 1      222
# 2      32e
# 3    kcmdk
# Name: col, dtype: object

# %%
dataframe = {
    'Names':['shiv','xyz','eee'],
    'Number':[2,3,4],
}

df = pd.DataFrame(dataframe)

# %%
df
# Out:
#   Names  Number
# 0  shiv       2
# 1   xyz       3
# 2   eee       4

# %%
df = pd.read_csv('df_arabica_clean.csv')

# %%
df.drop(['Unnamed: 0','ID'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#   Country of Origin                 Farm Name  \
# 0          Colombia          Finca El Paraiso
# 1            Taiwan  Royal Bean Geisha Estate
#
#                                 Lot Number                      Mill  \
# 0                               CQU2022015          Finca El Paraiso
# 1  The 2022 Pacific Rim Coffee Summit,T037  Royal Bean Geisha Estate
#
#   ICO Number                   Company   Altitude          Region  \
# 0        NaN      Coffee Quality Union  1700-1930  Piendamo,Cauca
# 1        NaN  Taiwan Coffee Laboratory       1200          Chiayi
#
#                 Producer  Number of Bags  ... Total Cup Points  \
# 0  Diego Samuel Bermudez               1  ...            89.33
# 1                    曾福森               1  ...            87.58
#
#   Moisture Percentage Category One Defects Quakers       Color  \
# 0                11.8                    0       0       green
# 1                10.5                    0       0  blue-green
#
# ...

# %%
df.columns
# Out:
# Index(['Country of Origin', 'Farm Name', 'Lot Number', 'Mill', 'ICO Number',
#        'Company', 'Altitude', 'Region', 'Producer', 'Number of Bags',
#        'Bag Weight', 'In-Country Partner', 'Harvest Year', 'Grading Date',
#        'Owner', 'Variety', 'Status', 'Processing Method', 'Aroma', 'Flavor',
#        'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity', 'Clean Cup',
#        'Sweetness', 'Overall', 'Defects', 'Total Cup Points',
#        'Moisture Percentage', 'Category One Defects', 'Quakers', 'Color',
#        'Category Two Defects', 'Expiration', 'Certification Body',
#        'Certification Address', 'Certification Contact'],
#       dtype='object')

# %%
df.isna()
# Out:
#      Country of Origin  Farm Name  Lot Number   Mill  ICO Number  Company  \
# 0                False      False       False  False        True    False
# 1                False      False       False  False        True    False
# 2                False      False       False  False        True    False
# 3                False      False       False  False        True    False
# 4                False      False       False  False        True    False
# ..                 ...        ...         ...    ...         ...      ...
# 202              False      False       False  False        True    False
# 203              False      False       False  False       False    False
# 204              False      False       False  False       False    False
# 205              False      False       False  False        True    False
# 206              False      False       False  False       False    False
#
#      Altitude  Region  Producer  Number of Bags  ...  Total Cup Points  \
# ...

# %%
df = df.dropna()

# %%
filt = (df['ICO Number'] != 'non')
df = df[filt]

# %%
df['ICO Number'].values
# Out:
# array(['033/DE/503/002 and 033/DE/268/002', '010/0296/600',
#        '010/0475/0207', '033/DE/163/001', '010/1081',
#        'ICO: 010/ 0218/0065', '010/0891/00041', '11/35', '11/15/118',
#        '11/951/279', '11/441/50', '0033/0004', '002-1894-0006',
#        '2-237-05', '11/15/117', '11/54876/03', '5-0025-0131',
#        '13-111-027', '010/0148/0712', '010/ 0218/0065', '11/15/96',
#        '13-111-030', '11/441/49', '11/15/51', '11/15/59',
#        '033/DE/491/001', '010-0424-0586', '033/0010/022', '5-0025-0132',
#        '11/15/95', '11/54876/01', '010/0145/0064', '3-0068-00886',
#        '016-2028-0312', '11/441/50', '13-167-471', '3-0104-00202',
#        '11/35', '5-0025-0130', '033/0010/032', '13-167-471-2',
#        '13-111-059', '13-63-119', '3-59-0654', '3093', '13-167-181',
#        '017-053-0017', '3/01/12857', '13-63-118', '9-392-35',
#        '29-169-003', '002/1643/0049', '13-111-057', '9-392-35',
# ...
